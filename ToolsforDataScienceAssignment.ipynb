# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Zuhal TUGRUL**
# ----------------
# Industrial Engineer

# %% [markdown]
# *I am interested in data science because I enjoy playing with large amounts of data*

# %% [markdown]
# ### My code in next cell will generate a random number between 0 and 9

# %%
import random

print(random.randint(0,9))
# Out:
# 3

# %% [markdown]
# - one
# - two
# 3. three
# 4. four
# - five
# - six
#
# ![IMG_4119.JPG](attachment:1dcb6f98-d6c3-4d61-86be-7f47303ca1a0.JPG) ~~previous image is a photo of tree that I took last year~~
#
# >I hope this course will be useful for all of us
#
#
#
# col1   |col2   |col3
# -------|-------|----
# data1  |data2  |data3
# data4  |data5  |data6
#
#
# ```I tried perfoming most of asked questions.```
